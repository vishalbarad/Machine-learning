# %%
pwd
# Out:
# '/Users/vishalbarad/Desktop/Python/ML/Data_preprocessing'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/vishalbarad/Desktop/Python/ML/Data_preprocessing/House_Price.csv')

# %%
df.head()
# Out:
#    price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 0   24.0       32.31     0.538     6.575  65.2   4.35   3.81   4.18   4.01
# 1   21.6       37.07     0.469     6.421  78.9   4.99   4.70   5.12   5.06
# 2   34.7       37.07     0.469     7.185  61.1   5.03   4.86   5.01   4.97
# 3   33.4       32.18     0.458     6.998  45.8   6.21   5.93   6.16   5.96
# 4   36.2       32.18     0.458     7.147  54.2   6.16   5.86   6.37   5.86
#
#    teachers  poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall  \
# 0      24.7       4.98     YES       5.480      11.1920     River        23
# 1      22.2       9.14      NO       7.332      12.1728      Lake        42
# 2      22.2       4.03      NO       7.394     101.1200      None        38
# 3      21.3       2.94     YES       9.268      11.2672      Lake        45
# 4      21.3       5.33      NO       8.824      11.2896      Lake        55
#
#   bus_ter     parks  Sold
# 0     YES  0.049347     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   resid_area   506 non-null    float64
#  2   air_qual     506 non-null    float64
#  3   room_num     506 non-null    float64
#  4   age          506 non-null    float64
#  5   dist1        506 non-null    float64
#  6   dist2        506 non-null    float64
#  7   dist3        506 non-null    float64
#  8   dist4        506 non-null    float64
#  9   teachers     506 non-null    float64
#  10  poor_prop    506 non-null    float64
#  11  airport      506 non-null    object
#  12  n_hos_beds   498 non-null    float64
#  13  n_hot_rooms  506 non-null    float64
#  14  waterbody    506 non-null    object
#  15  rainfall     506 non-null    int64
#  16  bus_ter      506 non-null    object
#  17  parks        506 non-null    float64
# ...

# %% [markdown]
# ### - Here 12th row  (n_hos_beds   498 non-null    float64) has 498 values and all other column has  506 so we conclude that in this column has error or some missing values

# %%
df.describe()
# Out:
#             price  resid_area    air_qual    room_num         age       dist1  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854   41.136779    0.554695    6.284634   68.574901    3.971996
# std      9.182176    6.860353    0.115878    0.702617   28.148861    2.108532
# min      5.000000   30.460000    0.385000    3.561000    2.900000    1.130000
# 25%     17.025000   35.190000    0.449000    5.885500   45.025000    2.270000
# 50%     21.200000   39.690000    0.538000    6.208500   77.500000    3.385000
# 75%     25.000000   48.100000    0.624000    6.623500   94.075000    5.367500
# max     50.000000   57.740000    0.871000    8.780000  100.000000   12.320000
#
#             dist2       dist3       dist4    teachers   poor_prop  n_hos_beds  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  498.000000
# mean     3.628775    3.960672    3.618972   21.544466   12.653063    7.899767
# ...

# %% [markdown]
# ### - first we check mean and median(also called 50%) values. if both the values has huge difference then we consider tthat column as outlier.
# ### - If there is no huge difference between them then we check consicutive row values difference as we calculated below
# ### -  As we can see that the column 'n_hot_room' has outlier. How? ans: there are huge difference of the value between 75% and max. so that is why we count this as an outlier

# %% [markdown]
# ## <span style="color:red">- in order to see outlier in continuous(quantitative data) we use boxplot graph as below:</span>

# %%
a = plt.boxplot(df['n_hot_rooms']) #for seaborn use"sns.boxplot(y='column_name',data=datafram)"

# %% [markdown]
# ### here as we can see there are 2 outlier(outside the box)

# %%
b = plt.boxplot(df['rainfall'])

# %% [markdown]
# ### as we can see ther is no outlier above

# %% [markdown]
# ## There is another method to find the outlier as <span style="color:red">joinplot</span> in seaborn library

# %%
sns.jointplot(x='rainfall',y='Sold', data=df)

# %% [markdown]
# ### As we can see ther is a one outlier in above

# %% [markdown]
# ## <span style="color:red">- in order to see outlier in categorical data we use countplot(bar) graph as below:</span>

# %%
sns.countplot(x='airport',data=df)

# %%
sns.countplot(x='waterbody',data=df)

# %% [markdown]
# ### AS we can see that there is no outlier in above two countplot

# %%
sns.countplot(x='bus_ter',data=df)

# %% [markdown]
# ### As we can see that there is no 'NO' in 'bus_ter' column so we can delete this column or we can say that this is an outlier because there is no effect of this column that only contains 'YES'

# %% [markdown]
# #### So what we found:
#   - missing values in 'n_hos_beds'
#   - 'bus_ter' provides no info so will drop it
#   - outliers in 'n_hot_rooms' and 'rainfall'
# ### Now we will see how to handel these problems

# %% [markdown]
# ## Now we will treate the outlier as follw

# %%
np.percentile(df['n_hot_rooms'],[99]) #we take 99 percentile of 'n_hot_column'.This returns array
# Out:
# array([15.39952])

# %%
np.percentile(df['n_hot_rooms'],[99])[0] #returns value
# Out:
# 15.399519999999999

# %%
uperval = np.percentile(df['n_hot_rooms'],[99])[0]

# %%
df[(df['n_hot_rooms']>uperval)]
# Out:
#      price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 2     34.7       37.07    0.4690     7.185  61.1   5.03   4.86   5.01   4.97
# 166   50.0       49.58    0.6050     7.929  96.2   2.11   1.91   2.31   1.86
# 204   50.0       32.68    0.4161     8.034  31.9   5.41   4.80   5.28   4.99
# 267   50.0       33.97    0.5750     8.297  67.0   2.60   2.13   2.43   2.52
# 369   50.0       48.10    0.6310     6.683  96.8   1.55   1.28   1.65   0.94
# 423   13.4       48.10    0.6140     6.103  85.1   2.08   1.80   2.34   1.87
#
#      teachers  poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall  \
# 2        22.2       4.03      NO       7.394       101.12      None        38
# 166      25.3       3.70     YES       8.300        15.40     River        37
# 204      25.3       2.88     YES       8.900        15.40     River        51
# 267      27.0       7.44     YES       8.000        15.40      None        42
# ...

# %%
df.n_hot_rooms[(df['n_hot_rooms']>uperval*3)]=uperval*3 #here we just multiply uperval with 3.here we can take any other num in place of 3
# Out:
# /Users/vishalbarad/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df[(df['n_hot_rooms']>uperval)] # as we can see that there is not huge difference between the column 'n_hot_rooms' values
# Out:
#      price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 2     34.7       37.07    0.4690     7.185  61.1   5.03   4.86   5.01   4.97
# 166   50.0       49.58    0.6050     7.929  96.2   2.11   1.91   2.31   1.86
# 204   50.0       32.68    0.4161     8.034  31.9   5.41   4.80   5.28   4.99
# 267   50.0       33.97    0.5750     8.297  67.0   2.60   2.13   2.43   2.52
# 369   50.0       48.10    0.6310     6.683  96.8   1.55   1.28   1.65   0.94
# 423   13.4       48.10    0.6140     6.103  85.1   2.08   1.80   2.34   1.87
#
#      teachers  poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall  \
# 2        22.2       4.03      NO       7.394     46.19856      None        38
# 166      25.3       3.70     YES       8.300     15.40000     River        37
# 204      25.3       2.88     YES       8.900     15.40000     River        51
# 267      27.0       7.44     YES       8.000     15.40000      None        42
# ...

# %%
np.percentile(df['rainfall'],[1]) # same as above but here we take lower value and multiply it with 0.3
# Out:
# array([20.])

# %%
np.percentile(df['rainfall'],[1])[0]
# Out:
# 20.0

# %%
lowerval = np.percentile(df['rainfall'],[1])[0]

# %%
df[(df['rainfall']<lowerval)]
# Out:
#      price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 213   28.1       40.59     0.489     6.375  32.3   4.11   3.92   4.18   3.57
#
#      teachers  poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall  \
# 213      21.4       9.38     YES       7.562      10.2248      None         3
#
#     bus_ter     parks  Sold
# 213     YES  0.044019     1

# %%
df.rainfall[(df['rainfall']<lowerval*0.3)] = lowerval*0.3
# Out:
# /Users/vishalbarad/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df[(df['rainfall']<lowerval)]
# Out:
#      price  resid_area  air_qual  room_num   age  dist1  dist2  dist3  dist4  \
# 213   28.1       40.59     0.489     6.375  32.3   4.11   3.92   4.18   3.57
#
#      teachers  poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall  \
# 213      21.4       9.38     YES       7.562      10.2248      None         6
#
#     bus_ter     parks  Sold
# 213     YES  0.044019     1

# %%
df.describe()
# Out:
#             price  resid_area    air_qual    room_num         age       dist1  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854   41.136779    0.554695    6.284634   68.574901    3.971996
# std      9.182176    6.860353    0.115878    0.702617   28.148861    2.108532
# min      5.000000   30.460000    0.385000    3.561000    2.900000    1.130000
# 25%     17.025000   35.190000    0.449000    5.885500   45.025000    2.270000
# 50%     21.200000   39.690000    0.538000    6.208500   77.500000    3.385000
# 75%     25.000000   48.100000    0.624000    6.623500   94.075000    5.367500
# max     50.000000   57.740000    0.871000    8.780000  100.000000   12.320000
#
#             dist2       dist3       dist4    teachers   poor_prop  n_hos_beds  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  498.000000
# mean     3.628775    3.960672    3.618972   21.544466   12.653063    7.899767
# ...

# %% [markdown]
# ## Now will handel the missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   resid_area   506 non-null    float64
#  2   air_qual     506 non-null    float64
#  3   room_num     506 non-null    float64
#  4   age          506 non-null    float64
#  5   dist1        506 non-null    float64
#  6   dist2        506 non-null    float64
#  7   dist3        506 non-null    float64
#  8   dist4        506 non-null    float64
#  9   teachers     506 non-null    float64
#  10  poor_prop    506 non-null    float64
#  11  airport      506 non-null    object
#  12  n_hos_beds   498 non-null    float64
#  13  n_hot_rooms  506 non-null    float64
#  14  waterbody    506 non-null    object
#  15  rainfall     506 non-null    int64
#  16  bus_ter      506 non-null    object
#  17  parks        506 non-null    float64
# ...

# %% [markdown]
# ### here 'n_hos_beds' column has missing value so we will handel or fill that missing values with their mean or avg score

# %%
df['n_hos_beds']=df['n_hos_beds'].fillna(df['n_hos_beds'].mean())

# %% [markdown]
# #### in order to change all dataframe's missing value : df = df.fillna(df.mean())

# %% [markdown]
# ### Now we perform data transformation. Here <span style="color:red"> dist1,dist2,dist3 and dist4 </span>represents the same meaning so we will take avg of those column and drop those 4 column as follw

# %%
df['dist_avg'] = (df.dist1+df.dist2+df.dist3+df.dist4)/4

# %%
df.describe()
# Out:
#             price  resid_area    air_qual    room_num         age       dist1  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854   41.136779    0.554695    6.284634   68.574901    3.971996
# std      9.182176    6.860353    0.115878    0.702617   28.148861    2.108532
# min      5.000000   30.460000    0.385000    3.561000    2.900000    1.130000
# 25%     17.025000   35.190000    0.449000    5.885500   45.025000    2.270000
# 50%     21.200000   39.690000    0.538000    6.208500   77.500000    3.385000
# 75%     25.000000   48.100000    0.624000    6.623500   94.075000    5.367500
# max     50.000000   57.740000    0.871000    8.780000  100.000000   12.320000
#
#             dist2       dist3       dist4    teachers   poor_prop  n_hos_beds  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.628775    3.960672    3.618972   21.544466   12.653063    7.899767
# ...

# %%
del df['dist1']
del df['dist2']
del df['dist3']
del df['dist4']

# %%
df.describe()
# Out:
#             price  resid_area    air_qual    room_num         age    teachers  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854   41.136779    0.554695    6.284634   68.574901   21.544466
# std      9.182176    6.860353    0.115878    0.702617   28.148861    2.164946
# min      5.000000   30.460000    0.385000    3.561000    2.900000   18.000000
# 25%     17.025000   35.190000    0.449000    5.885500   45.025000   19.800000
# 50%     21.200000   39.690000    0.538000    6.208500   77.500000   20.950000
# 75%     25.000000   48.100000    0.624000    6.623500   94.075000   22.600000
# max     50.000000   57.740000    0.871000    8.780000  100.000000   27.400000
#
#         poor_prop  n_hos_beds  n_hot_rooms    rainfall       parks  \
# count  506.000000  506.000000   506.000000  506.000000  506.000000
# mean    12.653063    7.899767    12.864050   39.187747    0.054454
# ...

# %%
del df['bus_ter'] # we also left to drop this column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bus_ter'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-8e0c03bc8755> in <module>
# ...

# %%
df.head()
# Out:
#    price  resid_area  air_qual  room_num   age  teachers  poor_prop airport  \
# 0   24.0       32.31     0.538     6.575  65.2      24.7       4.98     YES
# 1   21.6       37.07     0.469     6.421  78.9      22.2       9.14      NO
# 2   34.7       37.07     0.469     7.185  61.1      22.2       4.03      NO
# 3   33.4       32.18     0.458     6.998  45.8      21.3       2.94     YES
# 4   36.2       32.18     0.458     7.147  54.2      21.3       5.33      NO
#
#    n_hos_beds  n_hot_rooms waterbody  rainfall     parks  Sold  dist_avg
# 0       5.480     11.19200     River        23  0.049347     0    4.0875
# 1       7.332     12.17280      Lake        42  0.046146     1    4.9675
# 2       7.394     46.19856      None        38  0.045764     0    4.9675
# 3       9.268     11.26720      Lake        45  0.047151     0    6.0650
# 4       8.824     11.28960      Lake        55  0.039474     0    6.0625

# %% [markdown]
# ### Now we will se dummy variabels

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    price  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0   24.0       32.31     0.538     6.575  65.2      24.7       4.98
# 1   21.6       37.07     0.469     6.421  78.9      22.2       9.14
# 2   34.7       37.07     0.469     7.185  61.1      22.2       4.03
# 3   33.4       32.18     0.458     6.998  45.8      21.3       2.94
# 4   36.2       32.18     0.458     7.147  54.2      21.3       5.33
#
#    n_hos_beds  n_hot_rooms  rainfall     parks  Sold  dist_avg  airport_NO  \
# 0       5.480     11.19200        23  0.049347     0    4.0875           0
# 1       7.332     12.17280        42  0.046146     1    4.9675           1
# 2       7.394     46.19856        38  0.045764     0    4.9675           1
# 3       9.268     11.26720        45  0.047151     0    6.0650           0
# 4       8.824     11.28960        55  0.039474     0    6.0625           1
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_None  \
# ...

# %% [markdown]
# ### Here 'airport_NO' and 'waterbody_None' both are redundent column so we delete thos tow column

# %%
del df['airport_NO']

# %%
del df['waterbody_None']

# %%
df.head()
# Out:
#    price  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0   24.0       32.31     0.538     6.575  65.2      24.7       4.98
# 1   21.6       37.07     0.469     6.421  78.9      22.2       9.14
# 2   34.7       37.07     0.469     7.185  61.1      22.2       4.03
# 3   33.4       32.18     0.458     6.998  45.8      21.3       2.94
# 4   36.2       32.18     0.458     7.147  54.2      21.3       5.33
#
#    n_hos_beds  n_hot_rooms  rainfall     parks  Sold  dist_avg  airport_YES  \
# 0       5.480     11.19200        23  0.049347     0    4.0875            1
# 1       7.332     12.17280        42  0.046146     1    4.9675            0
# 2       7.394     46.19856        38  0.045764     0    4.9675            0
# 3       9.268     11.26720        45  0.047151     0    6.0650            1
# 4       8.824     11.28960        55  0.039474     0    6.0625            0
#
#    waterbody_Lake  waterbody_Lake and River  waterbody_River
# ...
